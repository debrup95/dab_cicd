-- %%
CREATE OR REFRESH MATERIALIZED VIEW st_orders
AS SELECT * FROM samples.nyctaxi.trips

-- %%
CREATE OR REPLACE MATERIALIZED VIEW
AS
SELECT
pickup_zip , count('*') as total_count
FROM LIVE.st_orders
GROUP BY pickup_zip
